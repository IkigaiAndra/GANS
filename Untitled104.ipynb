# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# Load and preprocess dataset
def load_real_images():
    (X_train, y_train), (_, _) = tf.keras.datasets.cifar10.load_data()
    X_train = X_train[np.where(y_train == 0)[0]]  # Use a subset (e.g., faces)
    X_train = (X_train - 127.5) / 127.5  # Normalize to [-1, 1]
    return X_train

# Generator model
def build_generator():
    model = tf.keras.Sequential([
        layers.Dense(256 * 8 * 8, activation="relu", input_dim=100),
        layers.Reshape((8, 8, 256)),
        layers.Conv2DTranspose(128, kernel_size=4, strides=2, padding="same", activation="relu"),
        layers.Conv2DTranspose(64, kernel_size=4, strides=2, padding="same", activation="relu"),
        layers.Conv2D(3, kernel_size=3, padding="same", activation="tanh"),
    ])
    return model

# Discriminator model
def build_discriminator():
    model = tf.keras.Sequential([
        layers.Conv2D(64, kernel_size=4, strides=2, padding="same", input_shape=(32, 32, 3)),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2D(128, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Flatten(),
        layers.Dense(1, activation="sigmoid"),
    ])
    return model

# GAN model
def build_gan(generator, discriminator):
    discriminator.trainable = False
    gan_input = layers.Input(shape=(100,))
    generated_image = generator(gan_input)
    gan_output = discriminator(generated_image)
    return tf.keras.Model(gan_input, gan_output)

# Training function
def train(generator, discriminator, gan, dataset, epochs=100000, batch_size=128):
    for epoch in range(epochs):
        # Train discriminator
        idx = np.random.randint(0, dataset.shape[0], batch_size)
        real_images = dataset[idx]
        fake_images = generator.predict(np.random.normal(0, 1, (batch_size, 100)))
        real_labels = np.ones((batch_size, 1))
        fake_labels = np.zeros((batch_size, 1))

        d_loss_real = discriminator.train_on_batch(real_images, real_labels)
        d_loss_fake = discriminator.train_on_batch(fake_images, fake_labels)

        # Train generator
        noise = np.random.normal(0, 1, (batch_size, 100))
        valid_labels = np.ones((batch_size, 1))
        g_loss = gan.train_on_batch(noise, valid_labels)

        # Log progress
        if epoch % 1000 == 0:
            print(f"{epoch} [D loss: {d_loss_real + d_loss_fake}] [G loss: {g_loss}]")

# Main execution
dataset = load_real_images()
generator = build_generator()
discriminator = build_discriminator()
gan = build_gan(generator, discriminator)

discriminator.compile(optimizer='adam', loss='binary_crossentropy')
gan.compile(optimizer='adam', loss='binary_crossentropy')

train(generator, discriminator, gan, dataset, epochs=100000)

# Load and preprocess dataset
def load_real_images():
    (X_train, y_train), (_, _) = tf.keras.datasets.cifar10.load_data()
    return X_train

# Generator model
def build_generator():
    model = tf.keras.Sequential([
        layers.Dense(256 * 8 * 8, activation="relu", input_dim=100),
        layers.Reshape((8, 8, 256)),
        layers.Conv2DTranspose(128, kernel_size=4, strides=2, padding="same", activation="relu"),
        layers.Conv2DTranspose(64, kernel_size=4, strides=2, padding="same", activation="relu"),
        layers.Conv2D(3, kernel_size=3, padding="same", activation="tanh"),
    ])
    return model

# Discriminator model
def build_discriminator():
    model = tf.keras.Sequential([
        layers.Conv2D(64, kernel_size=4, strides=2, padding="same", input_shape=(32, 32, 3)),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2D(128, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Flatten(),
        layers.Dense(1, activation="sigmoid"),
    ])
    return model

# GAN model
def build_gan(generator, discriminator):
    discriminator.trainable = False
    gan_input = layers.Input(shape=(100,))
    generated_image = generator(gan_input)
    gan_output = discriminator(generated_image)
    return tf.keras.Model(gan_input, gan_output)

# Training function
def train(generator, discriminator, gan, dataset, epochs=100000, batch_size=128):
    for epoch in range(epochs):
        # Train discriminator
        idx = np.random.randint(0, dataset.shape[0], batch_size)
        real_images = dataset[idx]
        fake_images = generator.predict(np.random.normal(0, 1, (batch_size, 100)))
        real_labels = np.ones((batch_size, 1))
        fake_labels = np.zeros((batch_size, 1))

        d_loss_real = discriminator.train_on_batch(real_images, real_labels)
        d_loss_fake = discriminator.train_on_batch(fake_images, fake_labels)

        # Train generator
        noise = np.random.normal(0, 1, (batch_size, 100))
        valid_labels = np.ones((batch_size, 1))
        g_loss = gan.train_on_batch(noise, valid_labels)

        # Log progress
        if epoch % 1000 == 0:
            print(f"{epoch} [D loss: {d_loss_real + d_loss_fake}] [G loss: {g_loss}]")

# Main execution
dataset = load_real_images()
generator = build_generator()
discriminator = build_discriminator()
gan = build_gan(generator, discriminator)

discriminator.compile(optimizer='adam', loss='binary_crossentropy')
gan.compile(optimizer='adam', loss='binary_crossentropy')

train(generator, discriminator, gan, dataset, epochs=100000)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 0 [D loss: 1.3862271308898926] [G loss: [array(0.69357425, dtype=float32), array(0.69357425, dtype=float32)]]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7a4255e3ef80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7a424c098d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 255ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 265ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 248ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 248ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 309ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
